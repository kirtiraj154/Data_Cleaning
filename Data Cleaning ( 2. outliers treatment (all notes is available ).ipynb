# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\KIRTI RAJ PRADHAN'

# %%
os.chdir("C:\\Users\\KIRTI RAJ PRADHAN\Downloads")

# %%
df=pd.read_excel("Book5.xlsx")

# %%
df
# Out:
#       CASENUM  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS  ATTORNEY
# 0           5     0.0       1.0       0.0    50.0  34.940         0
# 1           3     1.0       0.0       0.0    18.0   0.891         1
# 2          66     0.0       1.0       0.0     5.0   0.330         1
# 3          70     0.0       1.0       1.0    31.0   0.037         0
# 4          96     0.0       1.0       0.0    30.0   0.038         1
# ...       ...     ...       ...       ...     ...     ...       ...
# 1335    34100     0.0       1.0       0.0     NaN   0.576         1
# 1336    34110     1.0       1.0       0.0    46.0   3.705         0
# 1337    34113     1.0       1.0       0.0    39.0   0.099         1
# 1338    34145     1.0       0.0       0.0     8.0   3.177         0
# 1339    34153     1.0       1.0       0.0    30.0   0.688         1
#
# [1340 rows x 7 columns]

# %%
df.head()
# Out:
#    CASENUM  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS  ATTORNEY
# 0        5     0.0       1.0       0.0    50.0  34.940         0
# 1        3     1.0       0.0       0.0    18.0   0.891         1
# 2       66     0.0       1.0       0.0     5.0   0.330         1
# 3       70     0.0       1.0       1.0    31.0   0.037         0
# 4       96     0.0       1.0       0.0    30.0   0.038         1

# %%
df.describe(include='all')
# Out:
#             CASENUM       CLMSEX     CLMINSUR     SEATBELT       CLMAGE  \
# count   1340.000000  1328.000000  1299.000000  1292.000000  1151.000000
# mean   11202.001493     0.558735     0.907621     0.017028    28.414422
# std     9512.750796     0.496725     0.289671     0.129425    20.304451
# min        0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     4177.000000     0.000000     1.000000     0.000000     9.000000
# 50%     8756.500000     1.000000     1.000000     0.000000    30.000000
# 75%    15702.500000     1.000000     1.000000     0.000000    43.000000
# max    34153.000000     1.000000     1.000000     1.000000    95.000000
#
#               LOSS     ATTORNEY
# count  1340.000000  1340.000000
# mean      3.806307     0.488806
# std      10.636903     0.500061
# min       0.000000     0.000000
# 25%       0.400000     0.000000
# 50%       1.069500     0.000000
# 75%       3.781500     1.000000
# max     173.604000     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CASENUM   1340 non-null   int64
#  1   CLMSEX    1328 non-null   float64
#  2   CLMINSUR  1299 non-null   float64
#  3   SEATBELT  1292 non-null   float64
#  4   CLMAGE    1151 non-null   float64
#  5   LOSS      1340 non-null   float64
#  6   ATTORNEY  1340 non-null   int64
# dtypes: float64(5), int64(2)
# memory usage: 73.4 KB

# %%
df.isnull().sum()
# Out:
# CASENUM       0
# CLMSEX       12
# CLMINSUR     41
# SEATBELT     48
# CLMAGE      189
# LOSS          0
# ATTORNEY      0
# dtype: int64

# %%
df.rename(columns={"CLMSEX":"SEX","CLMAGE":"AGE"},inplace=True)

# %%
df
# Out:
#       CASENUM  SEX  CLMINSUR  SEATBELT   AGE    LOSS  ATTORNEY
# 0           5  0.0       1.0       0.0  50.0  34.940         0
# 1           3  1.0       0.0       0.0  18.0   0.891         1
# 2          66  0.0       1.0       0.0   5.0   0.330         1
# 3          70  0.0       1.0       1.0  31.0   0.037         0
# 4          96  0.0       1.0       0.0  30.0   0.038         1
# ...       ...  ...       ...       ...   ...     ...       ...
# 1335    34100  0.0       1.0       0.0   NaN   0.576         1
# 1336    34110  1.0       1.0       0.0  46.0   3.705         0
# 1337    34113  1.0       1.0       0.0  39.0   0.099         1
# 1338    34145  1.0       0.0       0.0   8.0   3.177         0
# 1339    34153  1.0       1.0       0.0  30.0   0.688         1
#
# [1340 rows x 7 columns]

# %%
sns.boxplot(x="LOSS",data=df)
plt.show()

# %%
df["LOSS"].fillna(df["LOSS"].median(),inplace=True)

# %%
df
# Out:
#       CASENUM  SEX  CLMINSUR  SEATBELT   AGE    LOSS  ATTORNEY
# 0           5  0.0       1.0       0.0  50.0  34.940         0
# 1           3  1.0       0.0       0.0  18.0   0.891         1
# 2          66  0.0       1.0       0.0   5.0   0.330         1
# 3          70  0.0       1.0       1.0  31.0   0.037         0
# 4          96  0.0       1.0       0.0  30.0   0.038         1
# ...       ...  ...       ...       ...   ...     ...       ...
# 1335    34100  0.0       1.0       0.0   NaN   0.576         1
# 1336    34110  1.0       1.0       0.0  46.0   3.705         0
# 1337    34113  1.0       1.0       0.0  39.0   0.099         1
# 1338    34145  1.0       0.0       0.0   8.0   3.177         0
# 1339    34153  1.0       1.0       0.0  30.0   0.688         1
#
# [1340 rows x 7 columns]

# %%
sns.boxplot(x="LOSS",data=df)
plt.show()

# %%
Q1=df["LOSS"].quantile(0.25)
Q3=df["LOSS"].quantile(0.75)
IQR=Q3-Q1
lower_limit=Q1-(IQR*1.5)
upper_limit=Q3+(IQR*1.5)
lower_limit,upper_limit
# Out:
# (-4.67225, 8.85375)

# %%
df[df["LOSS"]>8.85]
# Out:
#       CASENUM  SEX  CLMINSUR  SEATBELT   AGE    LOSS  ATTORNEY
# 0           5  0.0       1.0       0.0  50.0  34.940         0
# 11        148  0.0       1.0       0.0  41.0  19.610         0
# 22        550  0.0       0.0       0.0  38.0  16.161         0
# 24        580  0.0       1.0       0.0  54.0  10.040         1
# 43        941  1.0       1.0       0.0  55.0  13.100         1
# ...       ...  ...       ...       ...   ...     ...       ...
# 1179    30430  1.0       1.0       0.0  37.0  13.789         0
# 1188    30588  1.0       1.0       0.0  44.0  13.000         0
# 1256    31159  0.0       1.0       1.0  30.0  30.640         0
# 1286    33037  1.0       1.0       1.0  44.0  55.709         0
# 1312    33661  1.0       1.0       0.0  45.0  14.884         0
#
# [66 rows x 7 columns]

# %% [markdown]
# # Dwaling the outliers( 3'R' Technique)
# ## 1. Remove(Trimming: remove the outliers from our dataset)

# %%
df_trimmed=df[(df["LOSS"]>lower_limit) & (df["LOSS"]<upper_limit)]
df_trimmed
# Out:
#       CASENUM  SEX  CLMINSUR  SEATBELT   AGE   LOSS  ATTORNEY
# 1           3  1.0       0.0       0.0  18.0  0.891         1
# 2          66  0.0       1.0       0.0   5.0  0.330         1
# 3          70  0.0       1.0       1.0  31.0  0.037         0
# 4          96  0.0       1.0       0.0  30.0  0.038         1
# 5          97  1.0       1.0       0.0  35.0  0.309         0
# ...       ...  ...       ...       ...   ...    ...       ...
# 1335    34100  0.0       1.0       0.0   NaN  0.576         1
# 1336    34110  1.0       1.0       0.0  46.0  3.705         0
# 1337    34113  1.0       1.0       0.0  39.0  0.099         1
# 1338    34145  1.0       0.0       0.0   8.0  3.177         0
# 1339    34153  1.0       1.0       0.0  30.0  0.688         1
#
# [1274 rows x 7 columns]

# %%
sns.boxplot(x="LOSS",data=df_trimmed)
plt.show()      #again if you get the outlier then trimmed again by using new Q1,Q3,IQR and lower_limit,upper_limit

# %%
Q1=df_trimmed["LOSS"].quantile(0.25)
Q3=df_trimmed["LOSS"].quantile(0.75)
IQR=Q3-Q1
lower_limit=Q1-(IQR*1.5)
upper_limit=Q3+(IQR*1.5)
lower_limit,upper_limit
# Out:
# (-4.430000000000001, 8.408000000000001)

# %%
df_trimmed_one=df[(df["LOSS"]>lower_limit) & (df["LOSS"]<upper_limit)]
df_trimmed_one
# Out:
#       CASENUM  SEX  CLMINSUR  SEATBELT   AGE   LOSS  ATTORNEY
# 1           3  1.0       0.0       0.0  18.0  0.891         1
# 2          66  0.0       1.0       0.0   5.0  0.330         1
# 3          70  0.0       1.0       1.0  31.0  0.037         0
# 4          96  0.0       1.0       0.0  30.0  0.038         1
# 5          97  1.0       1.0       0.0  35.0  0.309         0
# ...       ...  ...       ...       ...   ...    ...       ...
# 1335    34100  0.0       1.0       0.0   NaN  0.576         1
# 1336    34110  1.0       1.0       0.0  46.0  3.705         0
# 1337    34113  1.0       1.0       0.0  39.0  0.099         1
# 1338    34145  1.0       0.0       0.0   8.0  3.177         0
# 1339    34153  1.0       1.0       0.0  30.0  0.688         1
#
# [1259 rows x 7 columns]

# %%
sns.boxplot(x="LOSS",data=df_trimmed_one)
plt.show()     #if get the outlier then again trimmed the (new data set) means df_trimmed_one

# %%
Q1=df_trimmed_one["LOSS"].quantile(0.25)
Q3=df_trimmed_one["LOSS"].quantile(0.75)
IQR=Q3-Q1
lower_limit=Q1-(IQR*1.5)
upper_limit=Q3+(IQR*1.5)
lower_limit,upper_limit
# Out:
# (-4.3525, 8.2635)

# %%
df_trimmed_two=df[(df["LOSS"]>lower_limit) & (df["LOSS"]<upper_limit)]
df_trimmed_two
# Out:
#       CASENUM  SEX  CLMINSUR  SEATBELT   AGE   LOSS  ATTORNEY
# 1           3  1.0       0.0       0.0  18.0  0.891         1
# 2          66  0.0       1.0       0.0   5.0  0.330         1
# 3          70  0.0       1.0       1.0  31.0  0.037         0
# 4          96  0.0       1.0       0.0  30.0  0.038         1
# 5          97  1.0       1.0       0.0  35.0  0.309         0
# ...       ...  ...       ...       ...   ...    ...       ...
# 1335    34100  0.0       1.0       0.0   NaN  0.576         1
# 1336    34110  1.0       1.0       0.0  46.0  3.705         0
# 1337    34113  1.0       1.0       0.0  39.0  0.099         1
# 1338    34145  1.0       0.0       0.0   8.0  3.177         0
# 1339    34153  1.0       1.0       0.0  30.0  0.688         1
#
# [1257 rows x 7 columns]

# %%
sns.boxplot(x="LOSS",data=df_trimmed_two)
plt.show()    #now complete the process

# %%
# if you don't get any outlier then you your work done is completed

# %% [markdown]
# ## 2. Replace the outliers ( it is the best one)

# %%
from feature_engine.outliers import Winsorizer

# %%
win=Winsorizer(capping_method="iqr",fold=1.5,tail="both",variables="LOSS")

# %%
df_win=win.fit_transform(df[["LOSS"]])
df_win
# Out:
#          LOSS
# 0     8.85375
# 1     0.89100
# 2     0.33000
# 3     0.03700
# 4     0.03800
# ...       ...
# 1335  0.57600
# 1336  3.70500
# 1337  0.09900
# 1338  3.17700
# 1339  0.68800
#
# [1340 rows x 1 columns]

# %%
print(win.left_tail_caps_,win.right_tail_caps_)
# Out:
# {'LOSS': -4.67225} {'LOSS': 8.85375}

# %%
sns.boxplot(x="LOSS",data=df_win)
plt.show()

# %% [markdown]
# ## 3. Replace Arbitrary Outliers Capper (the minimum and maximum values by a value determined by the user)
# ## . We get the min and max values based on domain expertise

# %%
from feature_engine.outliers import ArbitraryOutlierCapper

# %%
df["LOSS"].min()
# Out:
# 0.0

# %%
df["LOSS"].max()
# Out:
# 173.604

# %%
capper=ArbitraryOutlierCapper(max_capping_dict={'LOSS':6},
                              min_capping_dict={'LOSS':0.03})
df_c=capper.fit_transform(df[["LOSS"]])
df_c
# Out:
#        LOSS
# 0     6.000
# 1     0.891
# 2     0.330
# 3     0.037
# 4     0.038
# ...     ...
# 1335  0.576
# 1336  3.705
# 1337  0.099
# 1338  3.177
# 1339  0.688
#
# [1340 rows x 1 columns]

# %%
sns.boxplot(x="LOSS",data=df_c)
plt.show()
